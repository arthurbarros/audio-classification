# %%
import matplotlib.pyplot as plt
from scipy.io import wavfile

def graph_spectrogram(wav_file):
    rate, data = get_wav_info(wav_file)
    nfft = 256  # Length of the windowing segments
    fs = 256    # Sampling frequency
    pxx, freqs, bins, im = plt.specgram(data, nfft,fs)
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    plt.show()

def get_wav_info(wav_file):
    rate, data = wavfile.read(wav_file)
    return rate, data

graph_spectrogram('smp.wav')
graph_spectrogram('sample.wav')
# Out:
# /home/arthur/.virtualenvs/minisom/lib/python3.5/site-packages/matplotlib/axes/_axes.py:7235: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %%
from sklearn.ensemble import RandomForestClassifier


rate, data = get_wav_info('smp.wav')

# %%
clf = RandomForestClassifier(max_depth=2, random_state=0)
_ = clf.fit([data], [3])

# %%
clf.predict_proba([data])
# Out:
# array([[ 1.]])

# %%
clf.predict([data])
# Out:
# array([3])
